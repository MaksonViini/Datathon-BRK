# %%
import pandas as pd

# %%
bh = pd.read_csv('Data/bh.csv')
br = pd.read_csv('Data/110011.csv')

# %%
br.head(2)
# Out:
#     Ano              Município  \
# 0  2019  Ji-Paraná (Município)
# 1  2018  Ji-Paraná (Município)
#
#    Parcela_das_moradias_sem_banheiro_de_uso_exclusivo  \
# 0                                                0.0
# 1                                                0.0
#
#   Parcela_da_população_que_não_recebe_água_com_regularidade_adequada  \
# 0                                                  -
# 1                                                  -
#
#    Parcela_da_população_total_que_mora_em_domicílios_sem_acesso_à_água_tratada  \
# 0                                              0.334
# 1                                              0.336
#
#    Volume_de_água_consumida_per_capita Volume_de_esgoto_coletado  \
# 0                                88.15                         -
# 1                                86.52                       0.0
#
#   Volume_de_esgoto_tratado Volume_de_esgoto_não_tratado  Tarifa_média_de_água  \
# ...

# %%
bh.head(2)
# Out:
#     Ano                   Município  \
# 0  2019  Belo Horizonte (Município)
# 1  2018  Belo Horizonte (Município)
#
#    Parcela_das_moradias_sem_banheiro_de_uso_exclusivo  \
# 0                                              0.000
# 1                                              0.003
#
#   Parcela_da_população_que_não_recebe_água_com_regularidade_adequada  \
# 0                                              0.015
# 1                                              0.002
#
#    Parcela_da_população_total_que_mora_em_domicílios_sem_acesso_à_água_tratada  \
# 0                                              0.050
# 1                                              0.047
#
#    Volume_de_água_consumida_per_capita  Volume_de_esgoto_coletado  \
# 0                               151.63                  108635.54
# 1                               149.95                  106602.58
#
#    Volume_de_esgoto_tratado  Volume_de_esgoto_não_tratado  \
# ...

# %%
data = pd.concat([bh, br])
data.head(2)
# Out:
#     Ano                   Município  \
# 0  2019  Belo Horizonte (Município)
# 1  2018  Belo Horizonte (Município)
#
#    Parcela_das_moradias_sem_banheiro_de_uso_exclusivo  \
# 0                                              0.000
# 1                                              0.003
#
#   Parcela_da_população_que_não_recebe_água_com_regularidade_adequada  \
# 0                                              0.015
# 1                                              0.002
#
#    Parcela_da_população_total_que_mora_em_domicílios_sem_acesso_à_água_tratada  \
# 0                                              0.050
# 1                                              0.047
#
#    Volume_de_água_consumida_per_capita Volume_de_esgoto_coletado  \
# 0                               151.63                 108635.54
# 1                               149.95                 106602.58
#
#   Volume_de_esgoto_tratado Volume_de_esgoto_não_tratado  Tarifa_média_de_água  \
# ...

# %%
data.to_excel('Data/bh_br.xlsx', index=False)
